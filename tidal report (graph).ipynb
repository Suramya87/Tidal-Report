# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import norm

# %%
#setting up variables 
y_model = [6.57,-0.39,5.38,-1.74,5.26,-1.36,4.13,-1.15,3.48,-1.61,2.62,0.05,1.83,1.01,3.57,0.73,4.54,2.17,3.76,2.88,3.90,1.92,4.73,1.74,5.66,0.79,5.33,-0.04,5.23,-1.12,6.67,-0.61,4.74,-0.93,4.69,-1.29,4.20,0.22,3.68,0.26,2.47,0.36,2.59,0.99,4.10,1.87,3.17,1.60,3.71,3.10,4.04,2.49,4.07,2.18,5.93,0.70,6.89,0.21,6.72,0.22,6.77,-1.68,5.77,-1.32,4.35,-0.73,4.23,-0.38,2.24,-0.61,3.45,-0.46,4.13,1.21,3.34,2.58,3.32,3.26,5.21,2.39,4.83,2.41]
x_data = []
y_test = [] 
for i in range(0,len(y_model)):
    ######The function that is being tested########    z = np.sin(i) + np.sin(2*i)
    x_data.append(i)
    y_test.append(z)
print(str(len(y_model))+ " " +str(len(x_data)))
# Out:
# 82 82

# %%
# Plotting 
plt.plot(x_data, y_model, label='test model', color='red')
plt.plot(x_data, y_test) 
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

plt.legend()

# Save figure to PDF
plt.savefig('tidal_data_and_model.pdf')
plt.show()
